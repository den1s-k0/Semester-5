# %%
# !pip install matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('german_credit_risk.csv')
df.shape
# Out:
# (1000, 11)

# %%
df.tail(5)
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 995         995   31  female    1     own          little              NaN
# 996         996   40    male    3     own          little           little
# 997         997   38    male    2     own          little              NaN
# 998         998   23    male    2    free          little           little
# 999         999   27    male    2     own        moderate         moderate
#
#      Credit amount  Duration              Purpose  Risk
# 995           1736        12  furniture/equipment  good
# 996           3857        30                  car  good
# 997            804        12             radio/TV  good
# 998           1845        45             radio/TV   bad
# 999           4576        45                  car  good

# %%
df.head(5)
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
#
#    Credit amount  Duration              Purpose  Risk
# 0           1169         6             radio/TV  good
# 1           5951        48             radio/TV   bad
# 2           2096        12            education  good
# 3           7882        42  furniture/equipment  good
# 4           4870        24                  car   bad

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Sex', 'Job', 'Housing', 'Saving accounts',
#        'Checking account', 'Credit amount', 'Duration', 'Purpose', 'Risk'],
#       dtype='str')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.drop(columns=['Unnamed: 0'], inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1000 non-null   int64
#  1   Sex               1000 non-null   str
#  2   Job               1000 non-null   int64
#  3   Housing           1000 non-null   str
#  4   Saving accounts   817 non-null    str
#  5   Checking account  606 non-null    str
#  6   Credit amount     1000 non-null   int64
#  7   Duration          1000 non-null   int64
#  8   Purpose           1000 non-null   str
#  9   Risk              1000 non-null   str
# dtypes: int64(4), str(6)
# memory usage: 78.3 KB

# %%
df['Sex']
# Out:
# 0        male
# 1      female
# 2        male
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997      male
# 998      male
# 999      male
# Name: Sex, Length: 1000, dtype: str

# %%
df['Sex'].unique()
# Out:
# <StringArray>
# ['male', 'female']
# Length: 2, dtype: str

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      690
# female    310
# Name: count, dtype: int64

# %%
df['Saving accounts'].value_counts(dropna=False)
# Out:
# Saving accounts
# little        603
# NaN           183
# moderate      103
# quite rich     63
# rich           48
# Name: count, dtype: int64

# %%
df['Saving accounts'].value_counts()
# Out:
# Saving accounts
# little        603
# moderate      103
# quite rich     63
# rich           48
# Name: count, dtype: int64

# %%
df= df.dropna() 
df.shape
# Out:
# (522, 10)

# %%
df['Sex']
# Out:
# 1      female
# 3        male
# 4        male
# 7        male
# 9        male
#         ...
# 989      male
# 993      male
# 996      male
# 998      male
# 999      male
# Name: Sex, Length: 522, dtype: str

# %%
df
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 1     22  female    2     own          little         moderate           5951
# 3     45    male    2    free          little           little           7882
# 4     53    male    2    free          little           little           4870
# 7     35    male    3    rent          little         moderate           6948
# 9     28    male    3     own          little         moderate           5234
# ..   ...     ...  ...     ...             ...              ...            ...
# 989   48    male    1     own          little         moderate           1743
# 993   30    male    3     own          little           little           3959
# 996   40    male    3     own          little           little           3857
# 998   23    male    2    free          little           little           1845
# 999   27    male    2     own        moderate         moderate           4576
#
# ...

# %%
df.loc[4]
# Out:
# Age                     53
# Sex                   male
# Job                      2
# Housing               free
# Saving accounts     little
# Checking account    little
# Credit amount         4870
# Duration                24
# Purpose                car
# Risk                   bad
# Name: 4, dtype: object

# %%
df.iloc[2]
# Out:
# Age                     53
# Sex                   male
# Job                      2
# Housing               free
# Saving accounts     little
# Checking account    little
# Credit amount         4870
# Duration                24
# Purpose                car
# Risk                   bad
# Name: 4, dtype: object

# %%
df.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Conda\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:2761, in pandas._libs.hashtable.Int64HashTable.get_item()
# -> 2761 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:2785, in pandas._libs.hashtable.Int64HashTable.get_item()
# ...

# %%
df.loc[4].index
# Out:
# Index(['Age', 'Sex', 'Job', 'Housing', 'Saving accounts', 'Checking account',
#        'Credit amount', 'Duration', 'Purpose', 'Risk'],
#       dtype='str')

# %%
df.loc[4].values
# Out:
# array([np.int64(53), 'male', np.int64(2), 'free', 'little', 'little',
#        np.int64(4870), np.int64(24), 'car', 'bad'], dtype=object)

# %%
df.loc[4].to_dict()
# Out:
# {'Age': 53,
#  'Sex': 'male',
#  'Job': 2,
#  'Housing': 'free',
#  'Saving accounts': 'little',
#  'Checking account': 'little',
#  'Credit amount': 4870,
#  'Duration': 24,
#  'Purpose': 'car',
#  'Risk': 'bad'}

# %%
df.loc[4]['Risk']
# Out:
# 'bad'

# %%
df['Age'] +10
# Out:
# 1      32
# 3      55
# 4      63
# 7      45
# 9      38
#        ..
# 989    58
# 993    40
# 996    50
# 998    33
# 999    37
# Name: Age, Length: 522, dtype: int64

# %%
df.iloc[2,-1]
# Out:
# 'bad'

# %%
df['Sex'].apply(lambda x: 1 if x == 'male' else 0)
# Out:
# 1      0
# 3      1
# 4      1
# 7      1
# 9      1
#       ..
# 989    1
# 993    1
# 996    1
# 998    1
# 999    1
# Name: Sex, Length: 522, dtype: int64

# %%
df['Sex']= df['Sex'].apply(lambda x: 1 if x == 'male' else 0)

# %%
df ['X'] =1

# %%
df
# Out:
#      Age  Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 1     22    0    2     own          little         moderate           5951
# 3     45    1    2    free          little           little           7882
# 4     53    1    2    free          little           little           4870
# 7     35    1    3    rent          little         moderate           6948
# 9     28    1    3     own          little         moderate           5234
# ..   ...  ...  ...     ...             ...              ...            ...
# 989   48    1    1     own          little         moderate           1743
# 993   30    1    3     own          little           little           3959
# 996   40    1    3     own          little           little           3857
# 998   23    1    2    free          little           little           1845
# 999   27    1    2     own        moderate         moderate           4576
#
#      Duration              Purpose  Risk  X
# ...

# %%
mask = df['Housing']=='own'

# %%
mask
# Out:
# 1       True
# 3      False
# 4      False
# 7      False
# 9       True
#        ...
# 989     True
# 993     True
# 996     True
# 998    False
# 999     True
# Name: Housing, Length: 522, dtype: bool

# %%
df[mask]
# Out:
#      Age  Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 1     22    0    2     own          little         moderate           5951
# 9     28    1    3     own          little         moderate           5234
# 12    22    0    2     own          little         moderate           1567
# 13    60    1    1     own          little           little           1199
# 15    32    0    1     own        moderate           little           1282
# ..   ...  ...  ...     ...             ...              ...            ...
# 986   33    1    2     own          little             rich           6289
# 989   48    1    1     own          little         moderate           1743
# 993   30    1    3     own          little           little           3959
# 996   40    1    3     own          little           little           3857
# 999   27    1    2     own        moderate         moderate           4576
#
#      Duration              Purpose  Risk  X
# ...

# %%
df[(df['Housing']=='own') & (df['Age']>50)]
# Out:
#      Age  Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 13    60    1    1     own          little           little           1199
# 29    63    1    2     own          little           little           6836
# 77    51    1    2     own          little         moderate           4771
# 83    58    0    1     own          little           little           1755
# 84    52    1    1     own          little           little           2315
# 91    54    1    2     own          little           little           1409
# 94    54    1    2     own            rich         moderate           1318
# 137   66    1    1     own      quite rich         moderate            766
# 177   52    1    2     own      quite rich           little            338
# 179   65    1    2     own          little           little            571
# 213   66    1    3     own          little             rich           1908
# ...

# %%
df[-(df['Housing']=='own') & (df['Age']>50)]
# Out:
#      Age  Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 4     53    1    2    free          little           little           4870
# 44    58    0    1    free          little           little           6143
# 54    57    1    2    free          little         moderate           2225
# 62    61    1    3    free          little         moderate           1953
# 72    51    1    3    free          little           little           1164
# 75    66    1    3    free          little           little           1526
# 95    58    1    2    rent          little         moderate          15945
# 123   63    1    2    free          little             rich            781
# 163   70    1    3    free          little         moderate           7308
# 186   74    0    3    free          little         moderate           5129
# 187   68    1    0    free          little         moderate           1175
# ...

# %%
for i, row in df.iterrows():
    print (i,row)
    break
# Out:
# 1 Age                       22
# Sex                        0
# Job                        2
# Housing                  own
# Saving accounts       little
# Checking account    moderate
# Credit amount           5951
# Duration                  48
# Purpose             radio/TV
# Risk                     bad
# X                          1
# Name: 1, dtype: object

# %%
plt.scatter(df['Age'], df['Credit amount'], alpha = 0.3, marker ='*', c ='red')

# %%
fig, ax = plt.subplots(ncols=2,figsize=(12,6))
ax[0].scatter(df['Age'], df['Credit amount'], alpha = 0.3, marker ='*', c ='red')
ax[1].scatter(df['Duration'], df['Credit amount'], alpha = 0.3, marker ='*', c ='red')

# %%
x = df.groupby('Age')['Credit amount'].mean()

# %%
plt.plot(x.index,x.values,marker='*')

# %%
plt.hist(df['Age'])
# Out:
# (array([ 98., 145.,  80.,  71.,  43.,  31.,  24.,  12.,  14.,   4.]),
#  array([19. , 24.6, 30.2, 35.8, 41.4, 47. , 52.6, 58.2, 63.8, 69.4, 75. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(x.index,x.values)
# Out:
# <BarContainer object of 52 artists>
